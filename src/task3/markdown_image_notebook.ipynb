# %% [markdown]
# # Заголовок первого уровня
# Это демонстрация работы с **Markdown** в JupyterLab.
# Ниже будет представлено изображение.

# %%
from PIL import Image
import requests

image_url = "https://www.cloudera.com/content/dam/www/Downloads/Product%20Icons/Anaconda_Logo_0702.png"

im = Image.open(requests.get(image_url, stream=True).raw)
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1800x900>
